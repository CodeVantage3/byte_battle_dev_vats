# %%
import pandas as pd
df = pd.read_csv("supermarket_power_usage_10_days.csv")

# %%
df
# Out:
#            Date   Time  Temperature (°C)  Number of People  \
# 0    2024-11-01  00:00               9.0                 0
# 1    2024-11-01  01:00              10.2                 0
# 2    2024-11-01  02:00               9.7                 0
# 3    2024-11-01  03:00              11.5                 0
# 4    2024-11-01  04:00              12.5                 0
# ..          ...    ...               ...               ...
# 235  2024-11-10  19:00              12.7                 0
# 236  2024-11-10  20:00              11.5                 0
# 237  2024-11-10  21:00              10.5                 0
# 238  2024-11-10  22:00              10.7                 0
# 239  2024-11-10  23:00              10.2                 0
#
#      Air Conditioning Usage (kWh)  Lighting Usage (kWh)  \
# 0                            20.0                    20
# 1                            20.0                    20
# 2                            20.0                    20
# ...

# %%
df.head(48)
# Out:
#           Date   Time  Temperature (°C)  Number of People  \
# 0   2024-11-01  00:00               9.0                 0
# 1   2024-11-01  01:00              10.2                 0
# 2   2024-11-01  02:00               9.7                 0
# 3   2024-11-01  03:00              11.5                 0
# 4   2024-11-01  04:00              12.5                 0
# 5   2024-11-01  05:00              12.7                 0
# 6   2024-11-01  06:00              14.0                16
# 7   2024-11-01  07:00              15.3                66
# 8   2024-11-01  08:00              16.5               110
# 9   2024-11-01  09:00              17.5               154
# 10  2024-11-01  10:00              19.3               192
# 11  2024-11-01  11:00              19.8               199
# 12  2024-11-01  12:00              19.0               211
# 13  2024-11-01  13:00              19.8               200
# 14  2024-11-01  14:00              19.3               187
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df)
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
